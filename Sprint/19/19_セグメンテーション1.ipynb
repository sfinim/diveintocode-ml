# %% [markdown]
# ## セグメンテーション
#
# KaggleのTGS Salt Identification Challengeのデータセットを使用し、セグメンテーションを行います。
#
# [TGS Salt Identification Challenge | Kaggle](https://www.kaggle.com/c/tgs-salt-identification-challenge)
#
# セグメンテーション手法としてU-Net[1]を使います。
#
# [1]O.Ronneberger, P.Fischer, T.Brox. U-Net: Convolutional Networks for Biomedical Image Segmentation. Medical Image Computing and Computer-Assisted Intervention (MICCAI), Springer, LNCS, Vol.9351: 234–241, 2015
#
# [https://arxiv.org/pdf/1505.04597.pdf](https://arxiv.org/pdf/1505.04597.pdf)
#
# ### 【問題1】学習・推定
# 以下のKeras実装を使用して学習・推定を行ってください。
#
# [zhixuhao/unet: unet for image segmentation](https://github.com/zhixuhao/unet)
#
# 《GPU環境での学習》
#
# 大規模なデータセット、大きなモデルになるため、GPUを使用する必要があります。
#
# 《新たなデータセットの適用》
#
# 公開されている実装で用意されたものとは異なるデータセットを入力するための準備が必要です。

# %% [markdown]
# main.py, data.pyを修正し、ローカルで実行
#
# ```
# timanishi@:unet$ python main_2.py
# Using TensorFlow backend.
# 2020-09-29 16:35:32.207571: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-09-29 16:35:32.257261: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-29 16:35:32.258114: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce GTX 1070 with Max-Q Design major: 6 minor: 1 memoryClockRate(GHz): 1.2655
# pciBusID: 0000:01:00.0
# 2020-09-29 16:35:32.258689: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-09-29 16:35:32.261798: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-09-29 16:35:32.268836: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-09-29 16:35:32.270275: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-09-29 16:35:32.273472: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-09-29 16:35:32.276221: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-09-29 16:35:32.285157: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-09-29 16:35:32.285313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-29 16:35:32.285801: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-29 16:35:32.286424: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-09-29 16:35:32.287002: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-09-29 16:35:32.297378: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2020-09-29 16:35:32.298537: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55a3c30cef40 executing computations on platform Host. Devices:
# 2020-09-29 16:35:32.298558: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2020-09-29 16:35:32.369986: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-29 16:35:32.370365: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55a3c31618e0 executing computations on platform CUDA. Devices:
# 2020-09-29 16:35:32.370380: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): GeForce GTX 1070 with Max-Q Design, Compute Capability 6.1
# 2020-09-29 16:35:32.370704: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-29 16:35:32.370976: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce GTX 1070 with Max-Q Design major: 6 minor: 1 memoryClockRate(GHz): 1.2655
# pciBusID: 0000:01:00.0
# 2020-09-29 16:35:32.371008: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-09-29 16:35:32.371021: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-09-29 16:35:32.371032: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-09-29 16:35:32.371044: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-09-29 16:35:32.371055: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-09-29 16:35:32.371066: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-09-29 16:35:32.371077: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-09-29 16:35:32.371119: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-29 16:35:32.371409: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-29 16:35:32.371671: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-09-29 16:35:32.371896: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-09-29 16:35:32.373017: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-09-29 16:35:32.373028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-09-29 16:35:32.373033: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-09-29 16:35:32.373311: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-29 16:35:32.373616: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-09-29 16:35:32.373896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7073 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 6.1)
# /media/timanishi/Programing/2020/Dive_Into_Code/diveintocode-ml/Sprint/19/unet/model.py:55: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input = inputs, output = conv10)
# Epoch 1/40
# Found 4000 images belonging to 1 classes.
# Found 4000 images belonging to 1 classes.
# 2020-09-29 16:35:36.565484: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-09-29 16:35:37.250281: W tensorflow/stream_executor/cuda/redzone_allocator.cc:312] Not found: ./bin/ptxas not found
# Relying on driver to perform ptx compilation. This message will be only logged once.
# 300/300 [==============================] - 66s 221ms/step - loss: 0.6930 - accuracy: 0.7332
#
# Epoch 00001: loss improved from inf to 0.69296, saving model to unet_TGS.hdf5
# Epoch 2/40
# 300/300 [==============================] - 62s 207ms/step - loss: 0.6855 - accuracy: 0.7445
#
# Epoch 00002: loss improved from 0.69296 to 0.68550, saving model to unet_TGS.hdf5
# Epoch 3/40
# 300/300 [==============================] - 62s 208ms/step - loss: 0.6794 - accuracy: 0.7616
#
# Epoch 00003: loss improved from 0.68550 to 0.67940, saving model to unet_TGS.hdf5
# Epoch 4/40
# 300/300 [==============================] - 64s 213ms/step - loss: 0.6745 - accuracy: 0.7546
#
# Epoch 00004: loss improved from 0.67940 to 0.67450, saving model to unet_TGS.hdf5
# Epoch 5/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.6709 - accuracy: 0.7416
#
# Epoch 00005: loss improved from 0.67450 to 0.67092, saving model to unet_TGS.hdf5
# Epoch 6/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.6641 - accuracy: 0.7617
#
# Epoch 00006: loss improved from 0.67092 to 0.66412, saving model to unet_TGS.hdf5
# Epoch 7/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.6609 - accuracy: 0.7502
#
# Epoch 00007: loss improved from 0.66412 to 0.66092, saving model to unet_TGS.hdf5
# Epoch 8/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.6565 - accuracy: 0.7511
#
# Epoch 00008: loss improved from 0.66092 to 0.65653, saving model to unet_TGS.hdf5
# Epoch 9/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.6530 - accuracy: 0.7477
#
# Epoch 00009: loss improved from 0.65653 to 0.65303, saving model to unet_TGS.hdf5
# Epoch 10/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.6511 - accuracy: 0.7387
#
# Epoch 00010: loss improved from 0.65303 to 0.65107, saving model to unet_TGS.hdf5
# Epoch 11/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.6438 - accuracy: 0.7564
#
# Epoch 00011: loss improved from 0.65107 to 0.64375, saving model to unet_TGS.hdf5
# Epoch 12/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.6414 - accuracy: 0.7500
#
# Epoch 00012: loss improved from 0.64375 to 0.64143, saving model to unet_TGS.hdf5
# Epoch 13/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.6383 - accuracy: 0.7487
#
# Epoch 00013: loss improved from 0.64143 to 0.63832, saving model to unet_TGS.hdf5
# Epoch 14/40
# 300/300 [==============================] - 63s 209ms/step - loss: 0.6325 - accuracy: 0.7576
#
# Epoch 00014: loss improved from 0.63832 to 0.63254, saving model to unet_TGS.hdf5
# Epoch 15/40
# 300/300 [==============================] - 63s 209ms/step - loss: 0.6295 - accuracy: 0.7562
#
# Epoch 00015: loss improved from 0.63254 to 0.62945, saving model to unet_TGS.hdf5
# Epoch 16/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.6331 - accuracy: 0.7340
#
# Epoch 00016: loss did not improve from 0.62945
# Epoch 17/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.6179 - accuracy: 0.7725
#
# Epoch 00017: loss improved from 0.62945 to 0.61787, saving model to unet_TGS.hdf5
# Epoch 18/40
# 300/300 [==============================] - 62s 207ms/step - loss: 0.6247 - accuracy: 0.7423
#
# Epoch 00018: loss did not improve from 0.61787
# Epoch 19/40
# 300/300 [==============================] - 61s 204ms/step - loss: 0.6190 - accuracy: 0.7511
#
# Epoch 00019: loss did not improve from 0.61787
# Epoch 20/40
# 300/300 [==============================] - 61s 202ms/step - loss: 0.6168 - accuracy: 0.7498
#
# Epoch 00020: loss improved from 0.61787 to 0.61679, saving model to unet_TGS.hdf5
# Epoch 21/40
# 300/300 [==============================] - 62s 206ms/step - loss: 0.6161 - accuracy: 0.7452
#
# Epoch 00021: loss improved from 0.61679 to 0.61608, saving model to unet_TGS.hdf5
# Epoch 22/40
# 300/300 [==============================] - 62s 206ms/step - loss: 0.6037 - accuracy: 0.7695
#
# Epoch 00022: loss improved from 0.61608 to 0.60371, saving model to unet_TGS.hdf5
# Epoch 23/40
# 300/300 [==============================] - 62s 206ms/step - loss: 0.6145 - accuracy: 0.7377
#
# Epoch 00023: loss did not improve from 0.60371
# Epoch 24/40
# 300/300 [==============================] - 62s 207ms/step - loss: 0.6037 - accuracy: 0.7577
#
# Epoch 00024: loss improved from 0.60371 to 0.60367, saving model to unet_TGS.hdf5
# Epoch 25/40
# 300/300 [==============================] - 63s 211ms/step - loss: 0.5956 - accuracy: 0.7700
#
# Epoch 00025: loss improved from 0.60367 to 0.59558, saving model to unet_TGS.hdf5
# Epoch 26/40
# 300/300 [==============================] - 66s 219ms/step - loss: 0.5991 - accuracy: 0.7574
#
# Epoch 00026: loss did not improve from 0.59558
# Epoch 27/40
# 300/300 [==============================] - 64s 212ms/step - loss: 0.6173 - accuracy: 0.7160
#
# Epoch 00027: loss did not improve from 0.59558
# Epoch 28/40
# 300/300 [==============================] - 63s 212ms/step - loss: 0.5989 - accuracy: 0.7506
#
# Epoch 00028: loss did not improve from 0.59558
# Epoch 29/40
# 300/300 [==============================] - 63s 211ms/step - loss: 0.5927 - accuracy: 0.7589
#
# Epoch 00029: loss improved from 0.59558 to 0.59273, saving model to unet_TGS.hdf5
# Epoch 30/40
# 300/300 [==============================] - 66s 220ms/step - loss: 0.5988 - accuracy: 0.7439
#
# Epoch 00030: loss did not improve from 0.59273
# Epoch 31/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.5951 - accuracy: 0.7478
#
# Epoch 00031: loss did not improve from 0.59273
# Epoch 32/40
# 300/300 [==============================] - 63s 211ms/step - loss: 0.5894 - accuracy: 0.7552
#
# Epoch 00032: loss improved from 0.59273 to 0.58944, saving model to unet_TGS.hdf5
# Epoch 33/40
# 300/300 [==============================] - 64s 212ms/step - loss: 0.5919 - accuracy: 0.7480
#
# Epoch 00033: loss did not improve from 0.58944
# Epoch 34/40
# 300/300 [==============================] - 64s 213ms/step - loss: 0.5873 - accuracy: 0.7535
#
# Epoch 00034: loss improved from 0.58944 to 0.58731, saving model to unet_TGS.hdf5
# Epoch 35/40
# 300/300 [==============================] - 64s 212ms/step - loss: 0.5847 - accuracy: 0.7554
#
# Epoch 00035: loss improved from 0.58731 to 0.58467, saving model to unet_TGS.hdf5
# Epoch 36/40
# 300/300 [==============================] - 63s 211ms/step - loss: 0.5825 - accuracy: 0.7567
#
# Epoch 00036: loss improved from 0.58467 to 0.58248, saving model to unet_TGS.hdf5
# Epoch 37/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.5860 - accuracy: 0.7488
#
# Epoch 00037: loss did not improve from 0.58248
# Epoch 38/40
# 300/300 [==============================] - 63s 210ms/step - loss: 0.5815 - accuracy: 0.7542
#
# Epoch 00038: loss improved from 0.58248 to 0.58147, saving model to unet_TGS.hdf5
# Epoch 39/40
# 300/300 [==============================] - 63s 209ms/step - loss: 0.6044 - accuracy: 0.7170
#
# Epoch 00039: loss did not improve from 0.58147
# Epoch 40/40
# 300/300 [==============================] - 62s 206ms/step - loss: 0.5696 - accuracy: 0.7693
#
# Epoch 00040: loss improved from 0.58147 to 0.56960, saving model to unet_TGS.hdf5
# 18000/18000 [==============================] - 622s 35ms/step
#
#
# ```

# %%
import matplotlib.pyplot as plt
import glob 
from PIL import Image

# %%
img__list = glob.glob("unet/data/TGS/test/*")
img__list[:10]
# Out:
# ['unet/data/TGS/test/0005bb9630.png',
#  'unet/data/TGS/test/0005bb9630_predict.png',
#  'unet/data/TGS/test/000a68e46c.png',
#  'unet/data/TGS/test/000a68e46c_predict.png',
#  'unet/data/TGS/test/000c8dfb2a.png',
#  'unet/data/TGS/test/000c8dfb2a_predict.png',
#  'unet/data/TGS/test/000d0a5f6c.png',
#  'unet/data/TGS/test/000d0a5f6c_predict.png',
#  'unet/data/TGS/test/001ef8fc87.png',
#  'unet/data/TGS/test/001ef8fc87_predict.png']

# %%
for img_path in img__list[:10]:
    with Image.open(img_path) as img:
        plt.rcParams['figure.figsize'] = (5.0, 5.0)
        plt.imshow(img)
        plt.show()

# %% [markdown]
# うまくいったのかよく分からない…
#
# zhixuhaoの実装で使用されていたデータについては、うまくセグメンテーションできていそうだった。

# %%
img__list = glob.glob("unet/data/membrane/test/*")
img__list[5:15]
# Out:
# ['unet/data/membrane/test/10.png',
#  'unet/data/membrane/test/10_predict.png',
#  'unet/data/membrane/test/11.png',
#  'unet/data/membrane/test/11_predict.png',
#  'unet/data/membrane/test/12.png',
#  'unet/data/membrane/test/12_predict.png',
#  'unet/data/membrane/test/13.png',
#  'unet/data/membrane/test/13_predict.png',
#  'unet/data/membrane/test/14.png',
#  'unet/data/membrane/test/14_predict.png']

# %%
for img_path in img__list[5:15]:
    with Image.open(img_path) as img:
        plt.rcParams['figure.figsize'] = (5.0, 5.0)
        plt.imshow(img)
        plt.show()

# %% [markdown]
# ### 【問題2】コードリーディング
# 論文[1]に目を通した上で、上記実装のコードリーディングを行ってください。

# %% [markdown]
# #### モデルの定義：model.py unet関数
# 論文中の図にあるモデルの形になるようにコードが記述されている。
# 複数の層が直列に繋がっているものではないため、FunctionalAPIで書かれている。
#
# #### 入力サイズ
# 論文の図のモデルは572×572×1の入力を想定しているが、実装は256×256×1の大きさを想定している。adjustData関数で調整している。
