# %% [markdown]
# ## エイムズ市の住宅価格
# アイオワ州エイムズ市の住宅価格データセットを使い、基本的なデータの扱い方を学んでいきます。
#
#
# 住宅に関する79種類もの説明変数が用意されているため、それらと価格との関係を探索していきましょう。
#
#
# [エイムズ](https://en.wikipedia.org/wiki/Ames,_Iowa)がどのような街なのかもWikipediaなどで確認しておくと良いでしょう。

# %% [markdown]
# ### 【問題1】データセットの取得
# pd.read_csv()を使用して、変数に格納してください。

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# ### 【問題2】データセット自体の調査
# KaggleのOverviewページや、Dataページの「Data fields」などを読みながら、どのようなデータセットかを説明してください。

# %% [markdown]
# 【データセットについて】
#
# 住宅の特徴を述べる説明変数が79用意されており、住宅価格を目的変数として予測するためのものである。
#
# 【変数について】
#
# 以下に変数の説明をまとめる。
#
# | 変数名 | 説明(原文) | 説明(訳) |
# | :----- | :--------- | :------- |
# |SalePrice |the property's sale price in dollars. This is the target variable that you're trying to predict. |ドルでの販売価格。(※目的変数)|
# |MSSubClass |The building class |建物の種類 |
# |MSZoning |The general zoning classification |種類の一般的な分類|
# |LotFrontage |Linear feet of street connected to property |建物に接続された通りの長さ|
# |LotArea |Lot size in square feet |土地の面積|
# |Street | Type of road access |道路アクセスのタイプ|
# |Alley | Type of alley access |路地アクセスのタイプ|
# |LotShape | General shape of property |建物の一般的な形状|
# |LandContour | Flatness of the property |建物の平坦性|
# |Utilities | Type of utilities available |利用可能なユーティリティのタイプ|
# |LotConfig | Lot configuration |土地の構成|
# |LandSlope | Slope of property |建物の傾斜|
# |Neighborhood | Physical locations within Ames city limits |エイムズ市内の制限内の物理的な場所|
# |Condition1 | Proximity to main road or railroad |幹線道路または鉄道への近さ|
# |Condition2 | Proximity to main road or railroad (if a second is present) |幹線道路または鉄道への近さ(2つ目があれば)|
# |BldgType | Type of dwelling |住居の種類|
# |HouseStyle | Style of dwelling |住居のスタイル|
# |OverallQual | Overall material and finish quality |全体的な材料と仕上げの品質|
# |OverallCond | Overall condition rating |全体的な状態の評価|
# |YearBuilt | Original construction date |元の建設日|
# |YearRemodAdd | Remodel date |改造日|
# |RoofStyle | Type of roof |屋根のタイプ|
# |RoofMatl | Roof material |屋根の材質|
# |Exterior1st | Exterior covering on house |家の外装カバー|
# |Exterior2nd | Exterior covering on house (if more than one material) |家の外装カバー（もう一つ以上あれば）|
# |MasVnrType | Masonry veneer type |石積みのベニヤのタイプ|
# |MasVnrArea | Masonry veneer area in square feet |平方フィートの石積みベニア面積|
# |ExterQual | Exterior material quality |外装材質|
# |ExterCond | Present condition of the material on the exterior |外装材の現状|
# |Foundation | Type of foundation |基礎の種類|
# |BsmtQual | Height of the basement |地下室の高さ|
# |BsmtCond | General condition of the basement |地下室の概況|
# |BsmtExposure | Walkout or garden level basement walls |ストライキまたは庭レベルの地下壁|
# |BsmtFinType1 | Quality of basement finished area |地下の仕上がり面積|
# |BsmtFinSF1 | Type 1 finished square feet |タイプ1仕上げ済み平方フィート|
# |BsmtFinType2 | Quality of second finished area (if present) |2番目に完成した領域の品質（存在する場合）|
# |BsmtFinSF2 | Type 2 finished square feet |タイプ2仕上げ済み平方フィート|
# |BsmtUnfSF | Unfinished square feet of basement area |地下室の未完成の平方フィート|
# |TotalBsmtSF | Total square feet of basement area |地下室の総平方フィート|
# |Heating | Type of heating |暖房の種類|
# |HeatingQC | Heating quality and condition |暖房の品質と状態|
# |CentralAir | Central air conditioning |セントラルエアコン|
# |Electrical | Electrical system |電気系統|
# |1stFlrSF | First Floor square feet |1階の平方フィート|
# |2ndFlrSF | Second floor square feet |2階の平方フィート|
# |LowQualFinSF | Low quality finished square feet (all floors) |低品質の完成した平方フィート（すべてのフロア）|
# |GrLivArea | Above grade (ground) living area square feet |グレード（地上）のリビングエリアの平方フィート|
# |BsmtFullBath | Basement full bathrooms |地下フルバスルーム|
# |BsmtHalfBath | Basement half bathrooms |地下半分のバスルーム|
# |FullBath | Full bathrooms above grade |グレードを超えるフルバスルーム|
# |HalfBath | Half baths above grade |グレードを超える浴室|
# |Bedroom | Number of bedrooms above basement level |地下階より上の寝室の数|
# |Kitchen | Number of kitchens |キッチン数|
# |KitchenQual | Kitchen quality |キッチンの品質|
# |TotRmsAbvGrd | Total rooms above grade (does not include bathrooms) |グレードを超える部屋の総数（バスルームは含まれません）|
# |Functional | Home functionality rating |ホーム機能評価|
# |Fireplaces | Number of fireplaces |暖炉の数|
# |FireplaceQu | Fireplace quality |暖炉の質|
# |GarageType | Garage location |ガレージの場所|
# |GarageYrBlt | Year garage was built |ガレージが建てられた年|
# |GarageFinish | Interior finish of the garage |ガレージの内装仕上げ|
# |GarageCars | Size of garage in car capacity |車の容量のガレージのサイズ|
# |GarageArea | Size of garage in square feet |ガレージの平方フィートでのサイズ|
# |GarageQual | Garage quality |ガレージの品質|
# |GarageCond | Garage condition |ガレージの状態|
# |PavedDrive | Paved driveway |舗装された私道|
# |WoodDeckSF | Wood deck area in square feet |平方フィートのウッドデッキエリア|
# |OpenPorchSF | Open porch area in square feet |平方フィートのオープンポーチエリア|
# |EnclosedPorch | Enclosed porch area in square feet |平方フィートで囲まれたポーチエリア|
# |3SsnPorch | Three season porch area in square feet |平方フィートのスリーシーズンポーチエリア|
# |ScreenPorch | Screen porch area in square feet |平方フィートのスクリーンポーチエリア|
# |PoolArea | Pool area in square feet |平方フィートのプールエリア|
# |PoolQC | Pool quality |プールの質|
# |Fence | Fence quality |フェンスの品質|
# |MiscFeature | Miscellaneous feature not covered in other categories |他のカテゴリでカバーされていないその他の機能|
# |MiscVal | $Value of miscellaneous feature |その他の機能の価値|
# |MoSold | Month Sold |販売月|
# |YrSold | Year Sold |販売年|
# |SaleType | Type of sale |タイプの販売|
# |SaleCondition | Condition of sale |販売条件|

# %% [markdown]
# ### 【問題3】データの確認
# データを確認していきます。コードとマークダウンを組み合わせてレポートしてください。
#
# - 各特徴量がどういったものかを見る。（数値データか文字データなど）
# - 今回の目的変数はどの列か確認する。
# - 特徴量の平均値と標準偏差、四分位数を一度に表示させる。

# %%
# 各特徴量がどういったものかを見る。（数値データか文字データなど）
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# 今回の目的変数はどの列か確認する。

# %% [markdown]
# df.info()の結果より、80列目だと分かる。

# %%
# 特徴量の平均値と標準偏差、四分位数を一度に表示させる。
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# 一度にすべての特徴量について表示できないため、見えない部分はスライスで列を指定して表示。

# %%
df.iloc[:, 50:60].describe()
# Out:
#           HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000   1460.000000   1460.000000   1460.000000  1460.000000
# mean      0.382877      2.866438      1.046575      6.517808     0.613014
# std       0.502885      0.815778      0.220338      1.625393     0.644666
# min       0.000000      0.000000      0.000000      2.000000     0.000000
# 25%       0.000000      2.000000      1.000000      5.000000     0.000000
# 50%       0.000000      3.000000      1.000000      6.000000     1.000000
# 75%       1.000000      3.000000      1.000000      7.000000     1.000000
# max       2.000000      8.000000      3.000000     14.000000     3.000000
#
#        GarageYrBlt
# count  1379.000000
# mean   1978.506164
# std      24.689725
# min    1900.000000
# 25%    1961.000000
# 50%    1980.000000
# 75%    2002.000000
# max    2010.000000

# %% [markdown]
# スライスしたときに型が周りと合っていないと表示されないこともあるため注意する。
#
# その場合は、.describe()に「include='all'」を指定してあげると見える。

# %%
df.iloc[:, 50:60].describe(include='all')
# Out:
#            HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd  \
# count   1460.000000   1460.000000   1460.000000        1460   1460.000000
# unique          NaN           NaN           NaN           4           NaN
# top             NaN           NaN           NaN          TA           NaN
# freq            NaN           NaN           NaN         735           NaN
# mean       0.382877      2.866438      1.046575         NaN      6.517808
# std        0.502885      0.815778      0.220338         NaN      1.625393
# min        0.000000      0.000000      0.000000         NaN      2.000000
# 25%        0.000000      2.000000      1.000000         NaN      5.000000
# 50%        0.000000      3.000000      1.000000         NaN      6.000000
# 75%        1.000000      3.000000      1.000000         NaN      7.000000
# max        2.000000      8.000000      3.000000         NaN     14.000000
#
#        Functional   Fireplaces FireplaceQu GarageType  GarageYrBlt
# ...

# %% [markdown]
# ### 【問題4】欠損値への対応
# 欠損値に関して以下のことを行い、レポートしてください。
#
# - 各特徴量の欠損値の有無を確認する。
#
# 欠損値の確認にはmissingnoというライブラリを活用しましょう。このライブラリにより欠損値の有無が可視化できます。インストールや使い方に関しては以下のページをご覧ください。
#
# [ResidentMario/missingno: Missing data visualization module for Python.](https://github.com/ResidentMario/missingno)
#
# - 欠損値が何パーセント含まれるかを確認する。
# - 5つ以上欠損値がある特徴量（列）は削除する。
# - 欠損値があるサンプル（行）は削除する。

# %%
# 各特徴量の欠損値の有無を確認する。
import missingno as msno
# %matplotlib inline
msno.matrix(df)

# %%
msno.bar(df)

# %%
# 欠損値が何パーセント含まれるかを確認する。
(df.isnull().sum()/len(df['Id']))
# Out:
# Id               0.000000
# MSSubClass       0.000000
# MSZoning         0.000000
# LotFrontage      0.177397
# LotArea          0.000000
#                    ...
# MoSold           0.000000
# YrSold           0.000000
# SaleType         0.000000
# SaleCondition    0.000000
# SalePrice        0.000000
# Length: 81, dtype: float64

# %% [markdown]
# 上記結果をさらにインデックス(要素名)指定すれば、結果を細かく見ることができる。

# %%
(df.isnull().sum()/len(df['Id']))[70:82]
# Out:
# ScreenPorch      0.000000
# PoolArea         0.000000
# PoolQC           0.995205
# Fence            0.807534
# MiscFeature      0.963014
# MiscVal          0.000000
# MoSold           0.000000
# YrSold           0.000000
# SaleType         0.000000
# SaleCondition    0.000000
# SalePrice        0.000000
# dtype: float64

# %%
# 5つ以上欠損値がある特徴量（列）は削除する。
columns = df.columns
list_drop_column = []
for i, column in enumerate(columns):
    if df.iloc[:, i].isnull().sum() >= 5:
        list_drop_column.append(column)
        
df = df.drop(columns=list_drop_column)

df.shape
# Out:
# (1460, 63)

# %%
# 欠損値があるサンプル（行）は削除する。
list_drop_row = []
for i in range(df.shape[0]):
    if df.iloc[i].isnull().sum() > 0:
        list_drop_row.append(i)

df = df.drop(index=list_drop_row)

df.shape
# Out:
# (1459, 63)

# %% [markdown]
# ### 【問題5】用語の調査
# 以下の２つの単語を知る必要があります。これらを調査してまとめてください。
#
# - 尖度
# - 歪度

# %% [markdown]
# [BellCurveの統計学WEBにあったページ](https://bellcurve.jp/statistics/course/17950.html)を参照しました。

# %% [markdown]
# #### 尖度
# 分布が正規分布からどれだけ尖っているかを表す統計量で、山の尖り度と裾の広がり度を示します。サンプルサイズを$n$、各データ$x_i(i: 1, 2, ..., n)$の平均値を$\overline{x}$、標準偏差を$s$とすると尖度は次の式から求められます。
#
# $$
# \frac{n(n+1)}{(n-1)(n-2)(n-3)}\sum^n_{i=1}\frac{(x_i-\overline{x})^4}{s^4}-\frac{3(n-1)^2}{(n-2)(n-3)}
# $$
#
# 正規分布より尖った分布（データが平均付近に集中し、分布の裾が重い）のときには正の値を、正規分布より扁平な分布（データが平均付近から散らばり、分布の裾が軽い）のときには負の値をとります。正規分布の場合には0になります。

# %% [markdown]
# #### 歪度
# 分布が正規分布からどれだけ歪んでいるかを表す統計量で、左右対称性を示す指標のことです。サンプルサイズを$n$、各データ$x_i(i: 1, 2, ..., n)$の平均値を$\overline{x}$、標準偏差を$s$とすると歪度は次の式から求められます。
#
# $$
# \frac{n}{(n-1)(n-2)}\sum^n_{i=1}\left(\frac{x_i-\overline{x}}{s}\right)^3
# $$
#
# 「右裾が長い」もしくは「右に歪んだ」もしくは「左に偏った」分布のときには正の値を、「左裾が長い」もしくは「左に歪んだ」もしくは「右に偏った」分布のときには負の値をとります。左右対称の分布（例えば正規分布）の場合には0になります。

# %% [markdown]
# ### 【問題6】分布の確認
# - seabornのsns.distplot()を使い目的変数の分布を表示し、「尖度」と「歪度」も算出する。
# - 目的変数に対して対数変換を行う。
# - 対数変換したものに対して分布を表示し、「尖度」と「歪度」も算出する。
#
# 対数変換の前後での変化を「正規分布」という言葉を含めて説明してください。このように加工することで予測時の精度を上げることができます。
# [seaborn.distplot — seaborn 0.9.0 documentation](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %%
# seabornのsns.distplot()を使い目的変数の分布を表示し、「尖度」と「歪度」も算出する。
import seaborn as sns

sns.distplot(df['SalePrice'], bins=50)

# %%
print("尖度 :", df['SalePrice'].kurt())
print("歪度 :", df['SalePrice'].skew())
# Out:
# 尖度 : 6.529263049673958
# 歪度 : 1.8819429948035529

# %%
# 目的変数に対して対数変換を行う。
import numpy as np

df['SalePrice'] = df['SalePrice'].apply(np.log)
df['SalePrice']
# Out:
# 0       12.247694
# 1       12.109011
# 2       12.317167
# 3       11.849398
# 4       12.429216
#           ...
# 1455    12.072541
# 1456    12.254863
# 1457    12.493130
# 1458    11.864462
# 1459    11.901583
# Name: SalePrice, Length: 1459, dtype: float64

# %%
# 対数変換したものに対して分布を表示し、「尖度」と「歪度」も算出する。

sns.distplot(df['SalePrice'], bins=50)

# %%
print("尖度 :", df['SalePrice'].kurt())
print("歪度 :", df['SalePrice'].skew())
# Out:
# 尖度 : 0.806927847502148
# 歪度 : 0.12131775882415026

# %% [markdown]
# 対数変換後、データの分布に偏りがなくなり、正規分布に近づいた。

# %% [markdown]
# ### 【問題7】相関係数の確認
# 特徴量の確認をしていきます。それぞれに対してマークダウンで説明や考察を書いてください。
#
# - 相関係数行列のヒートマップを作り、相関係数の高い関係を見つける。
# - 目的変数との相関の高い特徴量10個を選び、これらだけの相関係数行列ヒートマップを作る。
# - 選んだ10個の特徴量が何か表しているかをKaggleのDataDescriptionの記述を参考に日本語でまとめる。
# - 選んだ10個の特徴量の中でお互いの相関係数が高い組み合わせを3つ探し出す。

# %%
# 相関係数行列のヒートマップを作り、相関係数の高い関係を見つける。
df_corr = df.corr()

sns.heatmap(df_corr, vmax=1, vmin=-1, center=0)

# %%
# 目的変数との相関の高い特徴量10個を選び、これらだけの相関係数行列ヒートマップを作る。
list_strong_corr = []

for column in df_corr.columns:
    if abs(df_corr.loc['SalePrice', column]) >= 0.5 and\
       column != 'SalePrice':
        list_strong_corr.append(column)

print(len(list_strong_corr))
print(list_strong_corr)
# Out:
# 10
# ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea']

# %%
df_strong_corr = df.loc[:, list_strong_corr].corr()
sns.heatmap(df_strong_corr, vmax=1, vmin=-1, center=0)

# %%
# 選んだ10個の特徴量が何か表しているかをKaggleのDataDescriptionの記述を参考に日本語でまとめる。

# %% [markdown]
# 抽出した特徴量について、問題2より抜粋。訳を一部修正。
#
#
# | 変数名 | 説明(原文) | 説明(訳) |
# | :----- | :--------- | :------- |
# |OverallQual | Overall material and finish quality |全体的な材料と仕上げの品質|
# |YearBuilt | Original construction date |元の建設日|
# |YearRemodAdd | Remodel date |改造日|
# |TotalBsmtSF | Total square feet of basement area |地下室の総平方フィート|
# |1stFlrSF | First Floor square feet |1階の平方フィート|
# |GrLivArea | Above grade (ground) living area square feet |地上のリビングエリアの平方フィート|
# |FullBath | Full bathrooms above grade |地上のフルバスルーム|
# |TotRmsAbvGrd | Total rooms above grade (does not include bathrooms) |地上の部屋の総数（バスルームは含まれません）|
# |GarageCars | Size of garage in car capacity |車の容量のガレージのサイズ|
# |GarageArea | Size of garage in square feet |ガレージの平方フィートでのサイズ|

# %%
# 選んだ10個の特徴量の中でお互いの相関係数が高い組み合わせを3つ探し出す。

# %% [markdown]
# 1. GarageCarsとGarageArea
# 2. GrLivAreaとTotRmsAbvGrd
# 3. TotRmsAbvGrdと1stFlrSF

# %%
df_strong_corr
# Out:
#               OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  \
# OverallQual      1.000000   0.573334      0.551605     0.537523  0.475933
# YearBuilt        0.573334   1.000000      0.592512     0.393159  0.283056
# YearRemodAdd     0.551605   0.592512      1.000000     0.292546  0.241344
# TotalBsmtSF      0.537523   0.393159      0.292546     1.000000  0.819393
# 1stFlrSF         0.475933   0.283056      0.241344     0.819393  1.000000
# GrLivArea        0.593021   0.199286      0.287677     0.455001  0.566084
# FullBath         0.551267   0.467960      0.438733     0.324886  0.381438
# TotRmsAbvGrd     0.427720   0.095401      0.191603     0.286125  0.409901
# GarageCars       0.600991   0.537866      0.420573     0.435279  0.439726
# GarageArea       0.561980   0.479460      0.372012     0.486719  0.489741
#
#               GrLivArea  FullBath  TotRmsAbvGrd  GarageCars  GarageArea
# OverallQual    0.593021  0.551267      0.427720    0.600991    0.561980
# ...

# %% [markdown]
# 問題では強い相関を3つだけ挙げたが、強い相関がありそうと勝手に思ったものに「YearBuiltとYearRemodAdd」がある。これらは分類としては「やや相関がある」部類に入る。パラメータの意味からなんとなく「強い相関」があると想像できそうなものでも、意外と強くはなかった。
# データを見て客観的に判断するって大事ですね。
